# %% [markdown]
# ![Q.1.png](attachment:Q.1.png)

# %%
def read_file(f):
    """Function to read a txt file and replace the original content with a new content."""
    
    # open the txt file in default read mode
    f = open("example.txt") 
    content = f.read()
    print(f"Original file content is ==> {content}")
    
    # Write a new string which will replace the original content of txt file.
    s = ("Placement should be replaced by screening.")
    print(f"New string is ==> {s}")
    # opening the file in reading and writing mode
    f = open("example.txt", "r+")
    
    
    f.truncate(0)
    f.write(s)
    f.close()
    print(f"'{content}' is replaced by '{s}'")
    print("Text successfully replaced")

read_file(f)
